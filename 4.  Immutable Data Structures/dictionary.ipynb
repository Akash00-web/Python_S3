# %%
x="Good morninG"
x=x.split(" ")
y={}
for i in x:
    y[i]=x.count(i)
    
print(y)
# Out:
# {'Good': 1, 'morninG': 1}

# %%
x="Good morninG"

y={}
for i in x:
    y[i]=x.count(i)
    
print(y)
# Out:
# {'G': 2, 'o': 3, 'd': 1, ' ': 1, 'm': 1, 'r': 1, 'n': 2, 'i': 1}

# %%
d = {
    "x": [10, 21, 25, 22],
    "y": [25, 15, 17, 18],
    "z": [12, 17, 9, 23],
    "q": [9, 19, 20, 25]
}


for key, scores in d.items():
    print(f"\n=== {key.upper()} ===")

   
    for i, score in enumerate(scores, start=1):
        print(f"T{i} = {score}")

 
    max_score = max(scores)
    avg_score = sum(scores) / len(scores)

    highest_phase_index = scores.index(max_score) + 1
    highest_phase = f"T{highest_phase_index}"

    print(f"Max Score = {max_score}")
    print(f"Average Score = {avg_score:.2f}")
    print(f"Highest marks got in phase: {highest_phase}")
# Out:
# === X ===
# T1 = 10
# T2 = 21
# T3 = 25
# T4 = 22
# Max Score = 25
# Average Score = 19.50
# Highest marks got in phase: T3
#
# === Y ===
# T1 = 25
# T2 = 15
# T3 = 17
# T4 = 18
# Max Score = 25
# Average Score = 18.75
# Highest marks got in phase: T1
#
# === Z ===
# T1 = 12
# T2 = 17
# T3 = 9
# T4 = 23
# Max Score = 23
# Average Score = 15.25
# Highest marks got in phase: T4
#
# === Q ===
# T1 = 9
# T2 = 19
# T3 = 20
# T4 = 25
# Max Score = 25
# Average Score = 18.25
# Highest marks got in phase: T4

# %%
x = int(input("Enter number: "))

d = {
  0: "zero", 1: "one", 2: "two", 3: "three", 4: "four", 5: "five", 6: "six",
  7: "seven", 8: "eight", 9: "nine", 10: "ten", 11: "eleven", 12: "twelve", 13: "thirteen",
  14: "fourteen", 15: "fifteen", 16: "sixteen", 17: "seventeen", 18: "eighteen", 19: "nineteen",
  20: "twenty", 30: "thirty", 40: "forty", 50: "fifty", 60: "sixty",
  70: "seventy", 80: "eighty", 90: "ninety"
}

def abc(n):
    if n <= 20:
        return d[n]
    if n < 100:
        if n % 10 == 0:
            return d[n]
        else:
            return d[n // 10 * 10] + " " + d[n % 10]
    if n < 1000:
        if n % 100 == 0:
            return d[n // 100] + " hundred"
        else:
            return d[n // 100] + " hundred " + abc(n % 100)

print(abc(x))
# Out:
# Enter number: 123
# one hundred twenty three
